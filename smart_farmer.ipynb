# %% [markdown]
# ## Importing our libraries

# %%
from functions import *

# %%
#add comment
#another comment

# %%
import pandas as pd
import numpy as np
import calendar

# %% [markdown]
# ### Importing Visualizations

# %%
#For visalizations 

import cufflinks as cf

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

cf.go_offline()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Uploading the data

# %%
crops=load_data('crops.csv')
crops.head()
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126    KES2205.00
# 1    Horticulture  Cooking Bananas  Med Bunch             22     KES511.00
# 2    Horticulture     Ripe Bananas  Med Bunch             14     KES616.00
# 3    Horticulture          Carrots    Ext Bag            138    KES2833.00
# 4    Horticulture         Tomatoes     Lg Box             64    KES3411.00
#
#                      Date  OBJECTID
# 0  01/01/2012 12:00:00 AM         0
# 1  01/01/2012 12:00:00 AM         1
# 2  01/01/2012 12:00:00 AM         2
# 3  01/01/2012 12:00:00 AM         3
# 4  01/01/2012 12:00:00 AM         4

# %%
#Upload data set 2 for main food crops per counties

# %%
counties = load_data('counties.csv')
counties.head()
# Out:
#    _id           County   CROP Area  (HA) Production  (Tons)  Yield ( Tons/HA)
# 0    1          BARINGO  Beans      15669              11034               0.7
# 1    2            BOMET  Beans      39002           50140.76               1.3
# 2    3          BUNGOMA  Beans      77367           61051.12               0.8
# 3    4            BUSIA  Beans      27351              36422               1.3
# 4    5  ELGEYO MARAKWET  Beans      14873           16354.62               1.1

# %%
# prices dataset
prices = load_data('prices.csv')

prices.head()
# Out:
#        COMMODITY     Unit     Kg      Nairobi      Mombasa       Kisumu  \
# 0      Dry Maize      Bag   90.0  2995.000000  3100.000000  3200.000000
# 1    Green Maize  Ext Bag  115.0  3199.583333  5155.416667  1990.000000
# 2  Finger Millet      Bag   90.0  5530.000000  6525.000000  7200.000000
# 3        Sorghum      Bag   90.0  3470.000000  3366.666667  3416.666667
# 4          Wheat      Bag   90.0          NaN          NaN          NaN
#
#         Nakuru  Eldoret  Malindi       Kitale   Kisii   Kitui    Busia  \
# 0  2380.000000   2600.0   3240.0  2261.111111  3200.0  3400.0  2373.75
# 1  1941.666667   1725.0   3000.0  1200.000000  3500.0  2000.0  1500.00
# 2  5311.250000   7200.0   5602.5  4500.000000  7300.0  7800.0  4725.00
# 3  3100.000000   3200.0   4357.5  1830.000000     NaN  4500.0  2475.00
# 4  3515.000000   2800.0   4500.0          NaN     NaN     NaN      NaN
#
#    Loitoktok  Garissa  Karatina    Embu      Average  Maximum.
# 0     3200.0   3600.0    2800.0  3000.0  2953.561508    3600.0
# 1     3250.0   6100.0    1000.0  2000.0  2682.976190    6100.0
# 2        NaN   7200.0    6000.0  5200.0  6161.057692    7800.0
# 3        NaN   6500.0    3000.0  4800.0  3667.986111    6500.0
# 4        NaN   5500.0    3500.0  4000.0  3969.166667    5500.0

# %%
crops.head(5)
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126    KES2205.00
# 1    Horticulture  Cooking Bananas  Med Bunch             22     KES511.00
# 2    Horticulture     Ripe Bananas  Med Bunch             14     KES616.00
# 3    Horticulture          Carrots    Ext Bag            138    KES2833.00
# 4    Horticulture         Tomatoes     Lg Box             64    KES3411.00
#
#                      Date  OBJECTID
# 0  01/01/2012 12:00:00 AM         0
# 1  01/01/2012 12:00:00 AM         1
# 2  01/01/2012 12:00:00 AM         2
# 3  01/01/2012 12:00:00 AM         3
# 4  01/01/2012 12:00:00 AM         4

# %% [markdown]
# ## Getting information on our dataset

# %%
check_info(crops)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1145 entries, 0 to 1144
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Produce_Variety  1145 non-null   object
#  1   Commodity_Type   1145 non-null   object
#  2   Unit             1145 non-null   object
#  3   Volume_in_Kgs    1145 non-null   int64
#  4   Values_in_Ksh    1143 non-null   object
#  5   Date             1145 non-null   object
#  6   OBJECTID         1145 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 62.7+ KB

# %% [markdown]
# ## Functions

# %%
#We will define all our functions here to use
#def means(values):
#  the_mean = sum(values)/len(values)
#  return the_mean

#Function to take in columns with spaces bewteen and retutn striped
#def strip(val):
 # striped = val.str.strip()
 # return striped

#checking for null

#def nuls(val):
#  no_null = val.isnull().sum()
#  return no_null

# Check for duplicates 
#def duplicates(val):
#  no_duplicate=val.duplicated().sum()
#  return no_duplicate

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Validity

# %%
counties.head()
# Out:
#    _id           County   CROP Area  (HA) Production  (Tons)  Yield ( Tons/HA)
# 0    1          BARINGO  Beans      15669              11034               0.7
# 1    2            BOMET  Beans      39002           50140.76               1.3
# 2    3          BUNGOMA  Beans      77367           61051.12               0.8
# 3    4            BUSIA  Beans      27351              36422               1.3
# 4    5  ELGEYO MARAKWET  Beans      14873           16354.62               1.1

# %%
# Ronald
#Drop illerevant columns, remove spaces at the beginign and end of  the columns

#Strip spaces within
strip((crops.Produce_Variety))
strip((crops.Commodity_Type))
#strip counties dataset
strip((counties.County))
strip((counties.CROP))
#strip((counties.Production__Tons))


#Replace KES with empty 
#strip(counties["Production__Tons"])
#counties["Production__Tons"]=counties["Production__Tons"].str.replace(",","")
crops['Values_in_Ksh'] = crops['Values_in_Ksh'].str.replace("KES","")

#Dataset 2 
counties['County']= counties['County'].str.strip()

crops['Values_in_Ksh'] = crops['Values_in_Ksh'].str.replace(",","")
#counties['Production__Tons']=counties['Production__Tons'].str.replace(" -   ","")
#counties['Production__Tons']=counties['Production__Tons'].str.replace(",","")


#counties['Production__Tons']=counties['Production__Tons'].str.replace(",","")
#counties['Production__Tons']=counties['Production__Tons'].str.replace(",","")

#counties['Production__Tons'].map(lambda x: float(x.replace(",","")))

# %% [markdown]
# ### Accuracy

# %%
#checking if related columns match

# %% [markdown]
# ### Completeness

# %% [markdown]
# #### checking for null values

# %%
# check for null values and either drop or fill
#fill null values in prices since we assume that all null means its not sold there 
prices.fillna(0, inplace=True)

# %%
prices.head()
# Out:
#        COMMODITY     Unit     Kg      Nairobi      Mombasa       Kisumu  \
# 0      Dry Maize      Bag   90.0  2995.000000  3100.000000  3200.000000
# 1    Green Maize  Ext Bag  115.0  3199.583333  5155.416667  1990.000000
# 2  Finger Millet      Bag   90.0  5530.000000  6525.000000  7200.000000
# 3        Sorghum      Bag   90.0  3470.000000  3366.666667  3416.666667
# 4          Wheat      Bag   90.0     0.000000     0.000000     0.000000
#
#         Nakuru  Eldoret  Malindi       Kitale   Kisii   Kitui    Busia  \
# 0  2380.000000   2600.0   3240.0  2261.111111  3200.0  3400.0  2373.75
# 1  1941.666667   1725.0   3000.0  1200.000000  3500.0  2000.0  1500.00
# 2  5311.250000   7200.0   5602.5  4500.000000  7300.0  7800.0  4725.00
# 3  3100.000000   3200.0   4357.5  1830.000000     0.0  4500.0  2475.00
# 4  3515.000000   2800.0   4500.0     0.000000     0.0     0.0     0.00
#
#    Loitoktok  Garissa  Karatina    Embu      Average  Maximum.
# 0     3200.0   3600.0    2800.0  3000.0  2953.561508    3600.0
# 1     3250.0   6100.0    1000.0  2000.0  2682.976190    6100.0
# 2        0.0   7200.0    6000.0  5200.0  6161.057692    7800.0
# 3        0.0   6500.0    3000.0  4800.0  3667.986111    6500.0
# 4        0.0   5500.0    3500.0  4000.0  3969.166667    5500.0

# %%
#checking nulls on crops dataset
#crops.isnull().sum()
nuls(crops)
# Out:
# Produce_Variety    0
# Commodity_Type     0
# Unit               0
# Volume_in_Kgs      0
# Values_in_Ksh      2
# Date               0
# OBJECTID           0
# dtype: int64

# %%
#Fill Na values with group mean using lambda

crops = crops.groupby(['Commodity_Type']).apply(lambda group: group.ffill())
#crops['Values_in_Ksh'].fillna(value= crops.groupby()means(crops['Commodity_Type']),inplace=True)

# %%
#check nul again 
nuls(crops)
# Out:
# Produce_Variety    0
# Commodity_Type     0
# Unit               0
# Volume_in_Kgs      0
# Values_in_Ksh      0
# Date               0
# OBJECTID           0
# dtype: int64

# %%
#chuck nuls in prices 
nuls(prices)
# Out:
# COMMODITY    0
# Unit         0
# Kg           0
# Nairobi      0
# Mombasa      0
# Kisumu       0
# Nakuru       0
# Eldoret      0
# Malindi      0
# Kitale       0
# Kisii        0
# Kitui        0
# Busia        0
# Loitoktok    0
# Garissa      0
# Karatina     0
# Embu         0
# Average      0
# Maximum.     0
# dtype: int64

# %%
#checking nulls on counties dataset
check_info(prices)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   COMMODITY  42 non-null     object
#  1   Unit       42 non-null     object
#  2   Kg         42 non-null     float64
#  3   Nairobi    42 non-null     float64
#  4   Mombasa    42 non-null     float64
#  5   Kisumu     42 non-null     float64
#  6   Nakuru     42 non-null     float64
#  7   Eldoret    42 non-null     float64
#  8   Malindi    42 non-null     float64
#  9   Kitale     42 non-null     float64
#  10  Kisii      42 non-null     float64
#  11  Kitui      42 non-null     float64
#  12  Busia      42 non-null     float64
#  13  Loitoktok  42 non-null     float64
#  14  Garissa    42 non-null     float64
#  15  Karatina   42 non-null     float64
#  16  Embu       42 non-null     float64
#  17  Average    42 non-null     float64
#  18  Maximum.   42 non-null     float64
# dtypes: float64(17), object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# ###Consistency

# %%
#dealing with duplicates 
#checking for duplicates in crops
duplicates(crops)


#No duplicates in the two datasets
# Out:
# 0

# %%
duplicates(prices)
# Out:
# 0

# %%
#checking for duplicates in counties
duplicates(counties)
# Out:
# 0

# %% [markdown]
# ### Uniformity

# %% [markdown]
# #### Columns

# %%
# Standaridization to fix messy columns to rename 
# example; officials_data.columns = officials_data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')','') 
# data type conversions like to pd.to_datetime 
counties.columns = counties.columns.str.strip().str.replace('(','').str.replace(')',"").str.replace(')',"").str.replace('/',"_per_").str.replace(' ',"_")
# Out:
# <ipython-input-25-4e7ba7ad5a28>:4: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
#Drop columns 
crops.drop(['OBJECTID'], axis = 1, inplace=True)

# %% [markdown]
# #### Data type conversion

# %%
#

# %%
#removing KES from Values in Ksh column
crops["Values_in_Ksh"]=crops["Values_in_Ksh"].str.replace("KES","")

# %%
crops.head(5)
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126       2205.00
# 1    Horticulture  Cooking Bananas  Med Bunch             22        511.00
# 2    Horticulture     Ripe Bananas  Med Bunch             14        616.00
# 3    Horticulture          Carrots    Ext Bag            138       2833.00
# 4    Horticulture         Tomatoes     Lg Box             64       3411.00
#
#                      Date
# 0  01/01/2012 12:00:00 AM
# 1  01/01/2012 12:00:00 AM
# 2  01/01/2012 12:00:00 AM
# 3  01/01/2012 12:00:00 AM
# 4  01/01/2012 12:00:00 AM

# %%
#convert crops value in ksh to integer
crops["Values_in_Ksh"]=crops["Values_in_Ksh"].astype(float)
#convert counties also for the production
#counties['Production__Tons'] = counties['Production__Tons'].astype(float)

# %%
#Convert Ha in counties to integer value

counties['Area__HA'] = counties['Area__HA'].str.replace(',','').str.replace(" -   ","")
counties['Area__HA']=pd.to_numeric(counties.Area__HA)

#counties['Production__Tons'] = pd.to_numeric(counties['Production__Tons'])

# %%
crops.head(5)
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs  Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126         2205.0
# 1    Horticulture  Cooking Bananas  Med Bunch             22          511.0
# 2    Horticulture     Ripe Bananas  Med Bunch             14          616.0
# 3    Horticulture          Carrots    Ext Bag            138         2833.0
# 4    Horticulture         Tomatoes     Lg Box             64         3411.0
#
#                      Date
# 0  01/01/2012 12:00:00 AM
# 1  01/01/2012 12:00:00 AM
# 2  01/01/2012 12:00:00 AM
# 3  01/01/2012 12:00:00 AM
# 4  01/01/2012 12:00:00 AM

# %%
#changing date
crops['Date'] =  pd.to_datetime(crops['Date'])

# %%
check_info(crops)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1145 entries, 0 to 1144
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Produce_Variety  1145 non-null   object
#  1   Commodity_Type   1145 non-null   object
#  2   Unit             1145 non-null   object
#  3   Volume_in_Kgs    1145 non-null   int64
#  4   Values_in_Ksh    1145 non-null   float64
#  5   Date             1145 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 94.9+ KB

# %%
crops.head()
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs  Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126         2205.0
# 1    Horticulture  Cooking Bananas  Med Bunch             22          511.0
# 2    Horticulture     Ripe Bananas  Med Bunch             14          616.0
# 3    Horticulture          Carrots    Ext Bag            138         2833.0
# 4    Horticulture         Tomatoes     Lg Box             64         3411.0
#
#         Date
# 0 2012-01-01
# 1 2012-01-01
# 2 2012-01-01
# 3 2012-01-01
# 4 2012-01-01

# %%
counties
# Out:
#      _id           County   CROP  Area__HA Production__Tons  \
# 0      1          BARINGO  Beans   15669.0            11034
# 1      2            BOMET  Beans   39002.0         50140.76
# 2      3          BUNGOMA  Beans   77367.0         61051.12
# 3      4            BUSIA  Beans   27351.0            36422
# 4      5  ELGEYO MARAKWET  Beans   14873.0         16354.62
# ..   ...              ...    ...       ...              ...
# 154  155     TAITA TAVETA   Rice     380.0             1320
# 155  156       TANA RIVER   Rice    1210.0             3855
# 156  157    THARAKA NITHI   Rice      28.0               79
# 157  158       WEST POKOT   Rice      20.0               72
# 158  159           VIHIGA   Rice       4.0               18
#
#      Yield__Tons_per_HA
# 0                   0.7
# 1                   1.3
# 2                   0.8
# 3                   1.3
# 4                   1.1
# ..                  ...
# 154                 3.5
# 155                 3.2
# 156                 2.8
# 157                 3.6
# 158                 4.5
#
# [159 rows x 6 columns]

# %%
counties.info
# Out:
# <bound method DataFrame.info of      _id           County   CROP  Area__HA Production__Tons  \
# 0      1          BARINGO  Beans   15669.0            11034
# 1      2            BOMET  Beans   39002.0         50140.76
# 2      3          BUNGOMA  Beans   77367.0         61051.12
# 3      4            BUSIA  Beans   27351.0            36422
# 4      5  ELGEYO MARAKWET  Beans   14873.0         16354.62
# ..   ...              ...    ...       ...              ...
# 154  155     TAITA TAVETA   Rice     380.0             1320
# 155  156       TANA RIVER   Rice    1210.0             3855
# 156  157    THARAKA NITHI   Rice      28.0               79
# 157  158       WEST POKOT   Rice      20.0               72
# 158  159           VIHIGA   Rice       4.0               18
#
#      Yield__Tons_per_HA
# 0                   0.7
# 1                   1.3
# 2                   0.8
# 3                   1.3
# 4                   1.1
# ..                  ...
# 154                 3.5
# 155                 3.2
# 156                 2.8
# 157                 3.6
# 158                 4.5
#
# [159 rows x 6 columns]>

# %% [markdown]
# #**Analysis Questions**

# %% [markdown]
# ## 1. What are the average market prices of various products?

# %%
# This output is the average value in Ksh per Commodity Type
df_average_value = crops.groupby('Commodity_Type').transform('mean')#['Values_in_Ksh']

df_average_value
# Out:
# <ipython-input-38-cf3aaca82bdc>:2: FutureWarning:
#
# Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the transforming function.
#       Volume_in_Kgs  Values_in_Ksh                          Date
# 0             126.0    2121.967742 2013-06-22 18:34:50.322580736
# 1              22.0     553.806452 2013-06-22 18:34:50.322580736
# 2              14.0     593.483871 2013-06-22 18:34:50.322580736
# 3             138.0    3565.000000 2013-06-22 18:34:50.322580736
# 4              64.0    3637.064516 2013-06-22 18:34:50.322580736
# ...             ...            ...                           ...
# 1140          110.0   11952.541667 2014-06-21 12:00:00.000000000
# 1141          110.0    2926.791667 2014-06-21 12:00:00.000000000
# 1142          110.0    2931.583333 2014-06-21 12:00:00.000000000
# 1143           99.0    1973.041667 2014-06-21 12:00:00.000000000
# 1144           98.0    2820.458333 2014-06-21 12:00:00.000000000
#
# [1145 rows x 3 columns]

# %%
# This output is the average value in Ksh per Produce Variety

#crops.groupby('Produce_Variety').mean()['Values_in_Ksh']
grouped_grops = crops.groupby('Produce_Variety')
#grouped_grops.get_group('Cereals')   # this will help get only specific group interested in

df_crops = grouped_grops.mean()#.drop(columns=['Volume_in_Kgs','Month','value_per_kg'])
#df_crops.reset_index(inplace=True)

# %%
df_crops['Values_in_Ksh'] .plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Produce_Variety'>

# %% [markdown]
# ## 2. What are the best regions to plant various commodities?

# %%
#Creating the mean coluln a acres 
#counties['Mean_Area_HA'] = counties.groupby('CROP').mean()['Area__HA'].apply(lambda x: x.mean())
#counties['Mean_Area_HA']
counties['Production__Tons']=counties['Production__Tons'].str.replace(",","")
counties['Production__Tons']=counties['Production__Tons'].str.replace(" -   ","")
counties['Production__Tons'] = pd.to_numeric(counties['Production__Tons'])

# %%
Av_Area = counties.groupby('CROP').mean()['Area__HA']
#Av_Area.columns=["CROP", "Average_area"]
Average_Area = Av_Area.reset_index()
Average_Area
Average_Area.columns=['CROP','Average_Area__HA']
Average_Area
# Out:
#              CROP  Average_Area__HA
# 0           Beans      26465.578723
# 1  Irish Potatoes       5745.310345
# 2            Rice       1401.809524
# 3         Sorghum       4443.340909
# 4           Wheat      10374.071429

# %%
#reste values of yields tons per hacre to have more than 2 decimals 
counties['Yield__Tons_per_HA'] = (counties['Production__Tons']/counties['Area__HA']).round(2)
counties.head()
# Out:
#    _id           County   CROP  Area__HA  Production__Tons  Yield__Tons_per_HA
# 0    1          BARINGO  Beans   15669.0          11034.00                0.70
# 1    2            BOMET  Beans   39002.0          50140.76                1.29
# 2    3          BUNGOMA  Beans   77367.0          61051.12                0.79
# 3    4            BUSIA  Beans   27351.0          36422.00                1.33
# 4    5  ELGEYO MARAKWET  Beans   14873.0          16354.62                1.10

# %%
#Have a dataframe with only counties whose crop area is more than hald average in the country
#This will deal with outliers in the regions wehere very minimla area is under such grop production 
counties_average = pd.merge(counties,Average_Area, on="CROP", how="inner")
counties_average.drop(columns=['_id'], inplace=True)
df_counties = counties_average[counties_average['Area__HA']>(counties_average['Average_Area__HA']*.5)]
df_counties
# Out:
#               County   CROP  Area__HA  Production__Tons  Yield__Tons_per_HA  \
# 0            BARINGO  Beans   15669.0          11034.00                0.70
# 1              BOMET  Beans   39002.0          50140.76                1.29
# 2            BUNGOMA  Beans   77367.0          61051.12                0.79
# 3              BUSIA  Beans   27351.0          36422.00                1.33
# 4    ELGEYO MARAKWET  Beans   14873.0          16354.62                1.10
# ..               ...    ...       ...               ...                 ...
# 140            BUSIA   Rice    1428.0           5715.00                4.00
# 146        KIRINYAGA   Rice   12015.0          49912.00                4.15
# 147           Kisumu   Rice    3570.0          13655.00                3.82
# 153            SIAYA   Rice    8345.0          29434.00                3.53
# 155       TANA RIVER   Rice    1210.0           3855.00                3.19
#
#      Average_Area__HA
# 0        26465.578723
# 1        26465.578723
# 2        26465.578723
# 3        26465.578723
# 4        26465.578723
# ..                ...
# 140       1401.809524
# 146       1401.809524
# 147       1401.809524
# 153       1401.809524
# 155       1401.809524
#
# [61 rows x 6 columns]

# %%
#Get a dataframe for max values
#we will only select ones with over 10,000 Hactares of land under that specific commodity
#df_counties = counties[counties['Area__HA']>100]

maxmum = df_counties.groupby(['CROP'])['Yield__Tons_per_HA'].transform(max) == df_counties['Yield__Tons_per_HA']

# %%
regions = df_counties[maxmum]
regions = regions.set_index('County')
regions
# Out:
#                            CROP  Area__HA  Production__Tons  \
# County
# BUSIA                     Beans   27351.0           36422.0
# HOMA BAY                Sorghum   18925.0           37440.0
# ELGEYO MARAKWET  Irish Potatoes   14958.0          224428.0
# MERU                      Wheat   10180.0           49475.0
# KIRINYAGA                  Rice   12015.0           49912.0
#
#                  Yield__Tons_per_HA  Average_Area__HA
# County
# BUSIA                          1.33      26465.578723
# HOMA BAY                       1.98       4443.340909
# ELGEYO MARAKWET               15.00       5745.310345
# MERU                           4.86      10374.071429
# KIRINYAGA                      4.15       1401.809524

# %% [markdown]
# ## 3. Which is the best duration to sell a specific commodity?

# %%
#Add months column to group by
crops['Month'] = crops['Date'].dt.month
crops.head()
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs  Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126         2205.0
# 1    Horticulture  Cooking Bananas  Med Bunch             22          511.0
# 2    Horticulture     Ripe Bananas  Med Bunch             14          616.0
# 3    Horticulture          Carrots    Ext Bag            138         2833.0
# 4    Horticulture         Tomatoes     Lg Box             64         3411.0
#
#         Date  Month
# 0 2012-01-01      1
# 1 2012-01-01      1
# 2 2012-01-01      1
# 3 2012-01-01      1
# 4 2012-01-01      1

# %%
a=crops.groupby(['Commodity_Type'])['Values_in_Ksh'].transform(max) == crops['Values_in_Ksh']
b=crops[a].groupby(['Month','Commodity_Type']).max()
b.drop(columns=['Produce_Variety','Date'])
# Out:
#                                  Unit  Volume_in_Kgs  Values_in_Ksh
# Month Commodity_Type
# 1     Oranges                     Bag             93         3795.0
# 2     Brinjals                    Bag             44         2126.0
#       Cooking Bananas       Med Bunch             22          629.0
#       Pawpaw                   Lg Box             54         2005.0
#       Ripe Bananas          Med Bunch             14          708.0
#       Sorghum                     Bag             90         4202.0
# 3     Cabbages                Ext Bag            126         3049.0
#       Capsicums                   Bag             50         3247.0
#       Cucumber                    Bag             50         2742.0
#       Kales                       Bag             50         2359.0
# 4     Cauliflower               crate             39         3781.0
#       Lemons                      Bag             95         2611.0
# 5     Avocado                     Bag             90         2705.0
#       Beans Mwitemania            Bag             90         6903.0
#       Beans Rosecoco              Bag             90         7522.0
#       Cassava Fresh               Bag             99         2350.0
#       Cowpeas                     Bag             90         7509.0
#       Finger Millet               Bag             90         7216.0
#       Fresh Peas                  Bag             51         4343.0
#       Green Gram                  Bag             90        11905.0
#       Green Maize             Ext Bag            115         3872.0
#       Limes                       net             13         1135.0
#       Red Irish Potatoes          Bag            110         3812.0
#       Spring Onions               Bag            142         2571.0
#       Tomatoes                 Lg Box             64         5664.0
#       White Irish Potatoes        Bag            110         3935.0
# 6     Beans Canadian              Bag             90         7471.0
#       Carrots                 Ext Bag            138         5715.0
#       Mwezi Moja                  Bag             90         7279.0
#       Onions Dry                  net             13         1259.0
#       Passion Fruits              Bag             57         4675.0
#       Sweet Potatoes              Bag             98         3259.0
#       Wheat                       Bag             90         4540.0
# 7     Groundnuts                  Bag            110        13713.0
# 9     Chillies                    Bag             38         3783.0
#       Lettuce                     Bag             51         4983.0
#       Mangoes Local               Bag            126         2688.0
#       Mangoes Ngowe         Sm Basket             25         1262.0
#       Pineapples                Dozen             13          935.0
# 12    Dolichos (Njahi)            Bag             90        12622.0
#       Dry Maize                   Bag             90         3037.0

# %%
#crops['Month'] = crops['Month'].apply(lambda x: calendar.month_abbr[x])

# %%
crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1145 entries, 0 to 1144
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Produce_Variety  1145 non-null   object
#  1   Commodity_Type   1145 non-null   object
#  2   Unit             1145 non-null   object
#  3   Volume_in_Kgs    1145 non-null   int64
#  4   Values_in_Ksh    1145 non-null   float64
#  5   Date             1145 non-null   datetime64[ns]
#  6   Month            1145 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 103.9+ KB

# %%
#b.drop(columns=['Produce_Variety','Date']).plot(kind = 'bar')
#b.plot(kind = 'bar', x='Month', y='Commodity_Type')  
#plot data
#fig, ax = plt.subplots(figsize=(15,7))
#data.groupby(['date','type']).count()['amount'].plot(ax=ax)
#crops[a].groupby(['Month']).count()['Commodity_Type'].plot(kind = 'bar')

#Shows the number of products sold in a particular month
#This shows that the month of May is peak in selling various commodites

# %%
# crop_per_month= crops[a].groupby(['Month']).count()['Commodity_Type']
# crop_per_month

# %%
crop_per_month= crops[a].groupby(['Month']).count()['Commodity_Type']
dd=dict((enumerate(calendar.month_abbr)))
crop_per_month = crop_per_month.rename(index=dd,level=0)
crop_per_month.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
crop_per_month = pd.DataFrame(crop_per_month)
crop_per_month.columns = ['Number_of_crops']
crop_per_month
# Out:
#        Number_of_crops
# Month
# Jan                  1
# Feb                  5
# Mar                  4
# Apr                  2
# May                 14
# Jun                  7
# Jul                  1
# Sep                  5
# Dec                  2

# %% [markdown]
# ## 4. What is the best selling commodity in various counties?

# %%
crops['value_per_kg']= (crops['Values_in_Ksh']/crops['Volume_in_Kgs']).round(2)
crops.head()
# Out:
#   Produce_Variety   Commodity_Type       Unit  Volume_in_Kgs  Values_in_Ksh  \
# 0    Horticulture         Cabbages    Ext Bag            126         2205.0
# 1    Horticulture  Cooking Bananas  Med Bunch             22          511.0
# 2    Horticulture     Ripe Bananas  Med Bunch             14          616.0
# 3    Horticulture          Carrots    Ext Bag            138         2833.0
# 4    Horticulture         Tomatoes     Lg Box             64         3411.0
#
#         Date  Month  value_per_kg
# 0 2012-01-01      1         17.50
# 1 2012-01-01      1         23.23
# 2 2012-01-01      1         44.00
# 3 2012-01-01      1         20.53
# 4 2012-01-01      1         53.30

# %%
counties.head()
# Out:
#    _id           County   CROP  Area__HA  Production__Tons  Yield__Tons_per_HA
# 0    1          BARINGO  Beans   15669.0          11034.00                0.70
# 1    2            BOMET  Beans   39002.0          50140.76                1.29
# 2    3          BUNGOMA  Beans   77367.0          61051.12                0.79
# 3    4            BUSIA  Beans   27351.0          36422.00                1.33
# 4    5  ELGEYO MARAKWET  Beans   14873.0          16354.62                1.10

# %%
df_counties[maxmum]
# Out:
#               County            CROP  Area__HA  Production__Tons  \
# 3              BUSIA           Beans   27351.0           36422.0
# 54          HOMA BAY         Sorghum   18925.0           37440.0
# 97   ELGEYO MARAKWET  Irish Potatoes   14958.0          224428.0
# 129             MERU           Wheat   10180.0           49475.0
# 146        KIRINYAGA            Rice   12015.0           49912.0
#
#      Yield__Tons_per_HA  Average_Area__HA
# 3                  1.33      26465.578723
# 54                 1.98       4443.340909
# 97                15.00       5745.310345
# 129                4.86      10374.071429
# 146                4.15       1401.809524

# %%
#Best selling commidity in various counties 
prices.head(20)
# Out:
#                  COMMODITY       Unit     Kg       Nairobi       Mombasa  \
# 0                Dry Maize        Bag   90.0   2995.000000   3100.000000
# 1              Green Maize    Ext Bag  115.0   3199.583333   5155.416667
# Garissa    5000.000000   675.000000  330.000000
# Karatina      0.000000   350.000000    0.000000
# Embu       1500.000000   500.000000  300.000000
#
# [14 rows x 42 columns]

# %%
Top_products_in_counties = New_prices.idxmax()
Top_products_in_counties.columns = ['Commodity', 'County']
Top_products_in_counties
# Out:
# COMMODITY
# Dry Maize                   Garissa
# Green Maize                 Garissa
# Finger Millet                 Kitui
# Sorghum                     Garissa
# Wheat                       Garissa
# Beans Canadian             Karatina
# Beans Rosecoco              Malindi
# Beans Mwitemania            Malindi
# Mwezi Moja                    Kitui
# Beans Dolichos (Njahi)      Malindi
# Green Gram                Loitoktok
# Cowpeas                      Kisumu
# Fresh Peas                  Garissa
# Groundnuts                  Garissa
# Red Irish Potatoes        Loitoktok
# White Irish Potatoes      Loitoktok
# Cassava Fresh               Malindi
# Sweet Potatoes              Garissa
# Cabbages                  Loitoktok
# Cooking Bananas             Malindi
# Ripe Bananas                  Busia
# Carrots                       Kitui
# Tomatoes                    Eldoret
# Onions Dry                   Kisumu
# Spring Onions               Garissa
# Chillies                    Garissa
# Cucumber                       Embu
# Capsicums                    Nakuru
# Brinjals                     Nakuru
# Cauliflower                 Nairobi
# Lettuce                     Malindi
# Passion Fruits              Mombasa
# Oranges                     Garissa
# Lemons                      Garissa
# Mangoes Local               Garissa
# Mangoes Ngowe                  Embu
# Limes                       Mombasa
# Pineapples                    Busia
# Pawpaw                      Garissa
# Avocado                     Malindi
# Kales                       Malindi
# Eggs                        Eldoret
# dtype: object

# %%
Top_products = pd.DataFrame(Top_products_in_counties)
Top_products.columns = ['County']

# %%
Top_products
# Out:
#                            County
# COMMODITY
# Dry Maize                 Garissa
# Green Maize               Garissa
# Finger Millet               Kitui
# Sorghum                   Garissa
# Wheat                     Garissa
# Beans Canadian           Karatina
# Beans Rosecoco            Malindi
# Beans Mwitemania          Malindi
# Mwezi Moja                  Kitui
# Beans Dolichos (Njahi)    Malindi
# Green Gram              Loitoktok
# Cowpeas                    Kisumu
# Fresh Peas                Garissa
# Groundnuts                Garissa
# Red Irish Potatoes      Loitoktok
# White Irish Potatoes    Loitoktok
# Cassava Fresh             Malindi
# Sweet Potatoes            Garissa
# Cabbages                Loitoktok
# Cooking Bananas           Malindi
# Ripe Bananas                Busia
# Carrots                     Kitui
# Tomatoes                  Eldoret
# Onions Dry                 Kisumu
# Spring Onions             Garissa
# Chillies                  Garissa
# Cucumber                     Embu
# Capsicums                  Nakuru
# Brinjals                   Nakuru
# Cauliflower               Nairobi
# Lettuce                   Malindi
# Passion Fruits            Mombasa
# Oranges                   Garissa
# Lemons                    Garissa
# Mangoes Local             Garissa
# Mangoes Ngowe                Embu
# Limes                     Mombasa
# Pineapples                  Busia
# Pawpaw                    Garissa
# Avocado                   Malindi
# Kales                     Malindi
# Eggs                      Eldoret

# %% [markdown]
# ### Output CSV files for streamlit app

# %%
regions.to_csv('df_regions.csv', index='County')
df_crops.to_csv("df_crops.csv", index='Produce_Variety')
crop_per_month.to_csv('df_crops_per_month.csv',index='Month')
Top_products.to_csv("df_to_products_per_county.csv",index='COMMODITY')
